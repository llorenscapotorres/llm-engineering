# %% [markdown]
# # Welcome to the Day 2 Lab!

# %% [markdown]
# ## First - let's talk about the Chat Completions API
#
# 1. The simplest way to call an LLM
# 2. It's called Chat Completions because it's saying: "here is a conversation, please predict what should come next"
# 3. The Chat Completions API was invented by OpenAI, but it's so popular that everybody uses it!
#
# ### We will start by calling OpenAI again - but don't worry non-OpenAI people, your time is coming!

# %% [markdown]
# ## And Ollama also gives an OpenAI compatible endpoint
#
# ...and it's on your local machine!
#
# If the next cell doesn't print "Ollama is running" then please open a terminal and run `ollama serve`

# %%
import requests

requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %%
from openai import OpenAI

OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# Get a fun fact

response = ollama.chat.completions.create(model="qwen3:latest", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# "Here's a fun fact for you: **Octopuses have three hearts!** Two of them pump blood to the gills, while the third pumps it to the rest of the body. Interestingly, when an octopus swims, the third heart actually *stops beating* to conserve energy. Once it stops moving, the heart restarts to keep the body supplied with oxygen-rich blood. Plus, octopuses can change color and texture in milliseconds to blend into their surroundings—nature’s ultimate stealthy superhero! 🐙✨"
